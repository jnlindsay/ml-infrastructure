# %% [markdown]
# # Model trainer runner

# %%
from trainers.grid_autoencoder_trainer import GridAutoencoderTrainer
from trainers.grid_counter_trainer import GridCounterTrainer
from trainers.xor_machine_trainer import XorMachineTrainer

# %%
grid_counter_trainer = GridCounterTrainer(32, 64, 10)
grid_counter_trainer.train(force_retrain=False)
grid_counter_trainer.demonstrate()
# Out:
# Loading model from file '/Users/jeremylindsay/Documents/Programming/ml-infrastructure/src/trainers/saved_models/grid_counter.pth'...
# Grid:
# Target count: 7.0
# Predicted count: [6.556718826293945]
# Mask memory:

# %% [markdown]
# ## XOR Machine

# %%
xor_machine_trainer = XorMachineTrainer(hidden_layer=False)
xor_machine_trainer.train()
xor_machine_trainer.demonstrate()
# Out:
# Epoch [0/1000], Loss: 1.5095865726470947
# Epoch [100/1000], Loss: 0.2500739097595215
# Epoch [200/1000], Loss: 0.25000011920928955
# Epoch [300/1000], Loss: 0.25
# Epoch [400/1000], Loss: 0.2499999850988388
# Epoch [500/1000], Loss: 0.25
# Epoch [600/1000], Loss: 0.25
# Epoch [700/1000], Loss: 0.25
# Epoch [800/1000], Loss: 0.25
# Epoch [900/1000], Loss: 0.25
#
# Predictions:
# tensor([[0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000]])

# %%
xor_machine_trainer = XorMachineTrainer(hidden_layer=True)
xor_machine_trainer.train()
xor_machine_trainer.demonstrate()
# Out:
# Epoch [0/1000], Loss: 0.7752015590667725
# Epoch [100/1000], Loss: 0.11375351250171661
# Epoch [200/1000], Loss: 0.0011490078177303076
# Epoch [300/1000], Loss: 5.362312549550552e-07
# Epoch [400/1000], Loss: 2.1716300979690573e-10
# Epoch [500/1000], Loss: 4.401479181126433e-13
# Epoch [600/1000], Loss: 2.32314167902814e-13
# Epoch [700/1000], Loss: 2.32314167902814e-13
# Epoch [800/1000], Loss: 2.32314167902814e-13
# Epoch [900/1000], Loss: 2.345901251032956e-13
#
# Predictions:
# tensor([[5.2154e-07],
#         [1.0000e+00],
#         [1.0000e+00],
#         [3.1292e-07]])
